# %%
print ("hello")
# Out:
# hello

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
train=pd.read_csv('candy-data.csv',index_col=0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 100 Grand to Whoppers
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chocolate         85 non-null     int64
#  1   fruity            85 non-null     int64
#  2   caramel           85 non-null     int64
#  3   peanutyalmondy    85 non-null     int64
#  4   nougat            85 non-null     int64
#  5   crispedricewafer  85 non-null     int64
#  6   hard              85 non-null     int64
#  7   bar               85 non-null     int64
#  8   pluribus          85 non-null     int64
#  9   sugarpercent      85 non-null     float64
#  10  pricepercent      85 non-null     float64
#  11  winpercent        85 non-null     float64
# dtypes: float64(3), int64(9)
# memory usage: 8.6+ KB

# %%
train.describe
# Out:
# <bound method NDFrame.describe of                             chocolate  fruity  caramel  peanutyalmondy  \
# competitorname
# 100 Grand                           1       0        1               0
# 3 Musketeers                        1       0        0               0
# One dime                            0       0        0               0
# One quarter                         0       0        0               0
# Air Heads                           0       1        0               0
# ...                               ...     ...      ...             ...
# Twizzlers                           0       1        0               0
# Warheads                            0       1        0               0
# WelchÕs Fruit Snacks                0       1        0               0
# WertherÕs Original Caramel          0       0        1               0
# Whoppers                            1       0        0               0
#
# ...

# %%
train.shape
# Out:
# (85, 12)

# %%
train.head
# Out:
# <bound method NDFrame.head of                             chocolate  fruity  caramel  peanutyalmondy  \
# competitorname
# 100 Grand                           1       0        1               0
# 3 Musketeers                        1       0        0               0
# One dime                            0       0        0               0
# One quarter                         0       0        0               0
# Air Heads                           0       1        0               0
# ...                               ...     ...      ...             ...
# Twizzlers                           0       1        0               0
# Warheads                            0       1        0               0
# WelchÕs Fruit Snacks                0       1        0               0
# WertherÕs Original Caramel          0       0        1               0
# Whoppers                            1       0        0               0
#
# ...

# %%
train.isnull().sum()
# Out:
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
sns.histplot(train)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 100 Grand to Whoppers
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chocolate         85 non-null     int64
#  1   fruity            85 non-null     int64
#  2   caramel           85 non-null     int64
#  3   peanutyalmondy    85 non-null     int64
#  4   nougat            85 non-null     int64
#  5   crispedricewafer  85 non-null     int64
#  6   hard              85 non-null     int64
#  7   bar               85 non-null     int64
#  8   pluribus          85 non-null     int64
#  9   sugarpercent      85 non-null     float64
#  10  pricepercent      85 non-null     float64
#  11  winpercent        85 non-null     float64
# dtypes: float64(3), int64(9)
# memory usage: 8.6+ KB

# %%
train.head(10)
# Out:
#                     chocolate  fruity  caramel  peanutyalmondy  nougat  \
# competitorname
# 100 Grand                   1       0        1               0       0
# 3 Musketeers                1       0        0               0       1
# One dime                    0       0        0               0       0
# One quarter                 0       0        0               0       0
# Air Heads                   0       1        0               0       0
# Almond Joy                  1       0        0               1       0
# Baby Ruth                   1       0        1               1       1
# Boston Baked Beans          0       0        0               1       0
# Candy Corn                  0       0        0               0       0
# Caramel Apple Pops          0       1        1               0       0
#
#                     crispedricewafer  hard  bar  pluribus  sugarpercent  \
# competitorname
# 100 Grand                          1     0    1         0         0.732
# ...

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:ylabel='competitorname'>

# %%
sns.countplot(x='chocolate',data=train)
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='count'>

# %%
sns.countplot(x='chocolate',hue='hard',data=train)
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='chocolate',y='winpercent',data=train)
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %%
sns.countplot(x='chocolate',hue='nougat',data=train)
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='count'>

# %%
sns.countplot(x='chocolate',hue='pluribus',data=train)
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='count'>

# %%
X=train.drop('chocolate',axis=1)
y=train['chocolate']

# %%
X.columns
# Out:
# Index(['fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer',
#        'hard', 'bar', 'pluribus', 'sugarpercent', 'pricepercent',
#        'winpercent'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
logmodel.coef_
# Out:
# array([[-2.05330534, -0.08544736, -0.25036654, -0.14411063,  0.12845517,
#         -0.31192919,  0.42456906, -0.78125119, -0.34835262,  0.37570109,
#          0.11199852]])

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        21
#            1       0.80      1.00      0.89         8
#
#     accuracy                           0.93        29
#    macro avg       0.90      0.95      0.92        29
# weighted avg       0.94      0.93      0.93        29

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,predictions)
print(cm)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.title('Possibility of being chocolate')
# Out:
# [[19  2]
#  [ 0  8]]
# Text(0.5, 1.0, 'Possibility of being chocolate')

# %%
score=logmodel.score(X_test,y_test)
print("Score: ",score)
print("Accuracy Percentage: %.3f"%(score*100),"%")
# Out:
# Score:  0.9310344827586207
# Accuracy Percentage: 93.103 %

# %%
sns.histplot(train)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
train["pricepercent"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
train.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="pricepercent",y="winpercent",data=train)
# Out:
# <AxesSubplot:xlabel='pricepercent', ylabel='winpercent'>

# %%
for i in df.select_dtypes (include='number'): sns.displot(df[i], kde = =True,bins=5) plt.show()
# Out:
#   File "C:\Users\KIIT\AppData\Local\Temp\ipykernel_6140\1505719880.py", line 1
#     for i in df.select_dtypes (include='number'): sns.displot(df[i], kde = =True,bins=5) plt.show()
#                                                                            ^
# SyntaxError: invalid syntax

# %%
sns.boxplot(x="pricepercent",y="winpercent",data=train)
for i in df.select_dtypes (include='number'): sns.displot(df[i], kde = =True,bins=5) plt
# Out:
#   File "C:\Users\KIIT\AppData\Local\Temp\ipykernel_6140\2677610188.py", line 2
#     for i in df.select_dtypes (include='number'): sns.displot(df[i], kde = =True,bins=5) plt
#                                                                            ^
# SyntaxError: invalid syntax

# %%
for i in train.select_dtypes(include='number'):
    sns.displot(train[i],kde = True,bins=5)
plt.show()

# %%
import lightgbm as lgb
lightgbm_ = lgb.LGBMRegressor()
reg = lightgbm_.fit(X_train, Y_train)
ypred = lightgbm_.predict(X_test
# Out:
#   File "C:\Users\KIIT\AppData\Local\Temp\ipykernel_6140\2557002888.py", line 4
#     ypred = lightgbm_.predict(X_test
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
# !pip install lightgbm
# Out:
# ...
#      ---------------------------------------- 1.0/1.0 MB 83.8 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import lightgbm as lgb
lightgbm_ = lgb.LGBMRegressor()
reg = lightgbm_.fit(X_train, y_train)
ypred = lightgbm_.predict(X_test)

# %%
sns.pairplot(train.head())
plt.show()
